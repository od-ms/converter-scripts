# %% [markdown]
# # Solaranlagen auf städtischen Gebäuden

# %%
import pandas as pd

# CSV-Datei laden
df = pd.read_csv('../../solar-und-windkraft-muenster/alle-anlagen-muenster.csv')

# Zeilen filtern, z.B. nur Zeilen mit Wert 'foo' in der ersten Spalte
gefiltert = df[(df['AnlagenbetreiberMaStRNummer'] == 'ABR979186451947') | (df['AnlagenbetreiberMaStRNummer'] == 'ABR990157438859')]
print(f"Anzahl Anlagen mit InbetriebnahmeDatum: {gefiltert["InbetriebnahmeDatum"].count()}")
gefiltert = gefiltert.sort_values(by="InbetriebnahmeDatum", ascending=True)
gefiltert.iloc[:5, :]
# Out:
# Anzahl Anlagen mit InbetriebnahmeDatum: 48
#             Id  AnlagenbetreiberId AnlagenbetreiberMaStRNummer  \
# 12091  1941244             1219237             ABR979186451947
# 10600  2975306             1887874             ABR990157438859
# 10411  3064402             1887874             ABR990157438859
# 11948  2136057             1219237             ABR979186451947
# 11947  2136035             1219237             ABR979186451947
#
#                               AnlagenbetreiberName  BetriebsStatusId  \
# 12091                                Stadt Münster                35
# 10600  Stadt Münster Amt für Mobilität und Tiefbau                35
# 10411  Stadt Münster Amt für Mobilität und Tiefbau                35
# 11948                                Stadt Münster                35
# 11947                                Stadt Münster                35
#
#       BetriebsStatusName DatumLetzteAktualisierung EinheitMeldeDatum  \
# 12091         In Betrieb                2025-03-26        2019-03-18
# 10600         In Betrieb                2020-04-15        2020-04-15
# 10411         In Betrieb                2022-02-23        2020-05-18
# 11948         In Betrieb                2025-03-26        2019-06-06
# 11947         In Betrieb                2025-03-26        2019-06-06
#
#                                   EinheitName InbetriebnahmeDatum  ...  \
# 12091  Stadt Münster_Bürgerzentrum Kinderhaus          1997-09-08  ...
# 10600                           Erbdrostenweg          2007-02-09  ...
# 10411                           Alter Postweg          2011-02-16  ...
# 11948          Stadt Münster_Kita Loddengrund          2018-12-10  ...
# 11947             Stadt Münster_Kita Burgwall          2018-12-10  ...
#
#            Ort    Plz  AnzahlSolarModule Bruttoleistung  \
# 12091  Münster  48159               56.0           5.04
# 10600  Münster  48167               26.0           4.94
# 10411  Münster  48155               36.0           7.82
# 11948  Münster  48167               28.0           8.40
# 11947  Münster  48165               28.0           8.40
#
#              EnergietraegerName  Flurstueck  IsAnonymisiert IsPilotwindanlage  \
# 12091  Solare Strahlungsenergie         NaN            True               NaN
# 10600  Solare Strahlungsenergie         NaN            True               NaN
# 10411  Solare Strahlungsenergie         NaN            True               NaN
# 11948  Solare Strahlungsenergie         NaN            True               NaN
# 11947  Solare Strahlungsenergie         NaN            True               NaN
#
#       LokationId  Nettonennleistung
# 12091  1925932.0                5.0
# 10600  2895282.0                4.2
# 10411  2980766.0                7.1
# 11948  2107244.0                8.0
# 11947  2107217.0                8.0
#
# [5 rows x 23 columns]

# %% [markdown]
# ## Felder
#
# ```
# DATEINAME;RAUM;QUELLE_INSTITUTION;THEMENBEREICH;MERKMAL;ZEIT;WERT;WERTEEINHEIT
# pv-anlagen;Stadt Münster - PV Anlage Grundschule Wolbeck-Nord (1443) Inbetriebnahme: 30.01.2020;Stadt Münster - Amt für Immobilienmanagement;15;Leistung ab Jahr
# ;2020;41,50;kWp
# pv-anlagen;Stadt Münster;Stadt Münster - Amt für Immobilienmanagement;15;Leistung aller Anlagen (Summe);2019;56,10;kWp
# ```

# %%
# iteriere über alle anlagen
pro_jahr_leistung = {}
pro_jahr_anzahl = {}
for index, row in gefiltert.iterrows():
    print(f"Anlage: {row['AnlagenbetreiberMaStRNummer']}, Leistung: {row['Nettonennleistung']}, Inbetriebnahme: {row['InbetriebnahmeDatum']}")  # Beispielausgabe
    inbetriebnahme = row['InbetriebnahmeDatum']
    if isinstance(inbetriebnahme, str) and len(inbetriebnahme) >= 4:
        jahr = inbetriebnahme[:4]  # Extrahiere das Jahr aus dem Datum
        pro_jahr_leistung[jahr] = pro_jahr_leistung.get(jahr, 0) + row['Nettonennleistung']
        pro_jahr_anzahl[jahr] = pro_jahr_anzahl.get(jahr, 0) + 1

leistungssummen = {}
anzahlsummen = {}
for jahr, wert in pro_jahr_leistung.items():
    leistungssummen[jahr] = sum(
        v for j, v in pro_jahr_leistung.items() if j <= jahr
    )
    anzahlsummen[jahr] = sum(
        v for j, v in pro_jahr_anzahl.items() if j <= jahr
    )

anzahlsummen
# Out:
# Anlage: ABR979186451947, Leistung: 5.0, Inbetriebnahme: 1997-09-08
# Anlage: ABR990157438859, Leistung: 4.2, Inbetriebnahme: 2007-02-09
# Anlage: ABR990157438859, Leistung: 7.1, Inbetriebnahme: 2011-02-16
# Anlage: ABR979186451947, Leistung: 8.0, Inbetriebnahme: 2018-12-10
# Anlage: ABR979186451947, Leistung: 8.0, Inbetriebnahme: 2018-12-10
# Anlage: ABR979186451947, Leistung: 8.0, Inbetriebnahme: 2018-12-10
# Anlage: ABR979186451947, Leistung: 19.8, Inbetriebnahme: 2018-12-11
# Anlage: ABR979186451947, Leistung: 5.7, Inbetriebnahme: 2019-06-17
# Anlage: ABR979186451947, Leistung: 4.0, Inbetriebnahme: 2019-06-17
# Anlage: ABR990157438859, Leistung: 19.44, Inbetriebnahme: 2019-08-20
# Anlage: ABR979186451947, Leistung: 30.0, Inbetriebnahme: 2020-01-30
# Anlage: ABR979186451947, Leistung: 60.0, Inbetriebnahme: 2020-02-12
# Anlage: ABR979186451947, Leistung: 29.48, Inbetriebnahme: 2020-12-03
# Anlage: ABR979186451947, Leistung: 29.48, Inbetriebnahme: 2020-12-03
# Anlage: ABR979186451947, Leistung: 29.9, Inbetriebnahme: 2021-02-02
# Anlage: ABR979186451947, Leistung: 5.92, Inbetriebnahme: 2021-08-10
# Anlage: ABR979186451947, Leistung: 5.0, Inbetriebnahme: 2021-08-10
# Anlage: ABR979186451947, Leistung: 99.0, Inbetriebnahme: 2021-11-23
# Anlage: ABR979186451947, Leistung: 55.0, Inbetriebnahme: 2022-01-01
# Anlage: ABR979186451947, Leistung: 45.0, Inbetriebnahme: 2022-05-11
# Anlage: ABR979186451947, Leistung: 4.0, Inbetriebnahme: 2022-08-29
# Anlage: ABR979186451947, Leistung: 57.76, Inbetriebnahme: 2023-02-28
# Anlage: ABR979186451947, Leistung: 96.2, Inbetriebnahme: 2023-04-11
# Anlage: ABR979186451947, Leistung: 24.75, Inbetriebnahme: 2023-07-04
# Anlage: ABR979186451947, Leistung: 99.96, Inbetriebnahme: 2023-08-30
# Anlage: ABR979186451947, Leistung: 60.0, Inbetriebnahme: 2023-10-19
# Anlage: ABR990157438859, Leistung: 3.0, Inbetriebnahme: 2023-11-27
# Anlage: ABR990157438859, Leistung: 8.14, Inbetriebnahme: 2023-11-30
# Anlage: ABR990157438859, Leistung: 7.0, Inbetriebnahme: 2023-11-30
# Anlage: ABR990157438859, Leistung: 10.0, Inbetriebnahme: 2023-11-30
# Anlage: ABR990157438859, Leistung: 8.14, Inbetriebnahme: 2023-12-06
# Anlage: ABR990157438859, Leistung: 7.0, Inbetriebnahme: 2023-12-08
# Anlage: ABR990157438859, Leistung: 15.0, Inbetriebnahme: 2023-12-08
# Anlage: ABR979186451947, Leistung: 6.0, Inbetriebnahme: 2023-12-12
# Anlage: ABR979186451947, Leistung: 75.0, Inbetriebnahme: 2023-12-12
# Anlage: ABR990157438859, Leistung: 35.0, Inbetriebnahme: 2023-12-21
# Anlage: ABR979186451947, Leistung: 20.0, Inbetriebnahme: 2024-02-09
# Anlage: ABR979186451947, Leistung: 29.75, Inbetriebnahme: 2024-02-21
# Anlage: ABR979186451947, Leistung: 15.0, Inbetriebnahme: 2024-03-15
# Anlage: ABR979186451947, Leistung: 29.76, Inbetriebnahme: 2024-04-22
# Anlage: ABR990157438859, Leistung: 10.0, Inbetriebnahme: 2024-05-13
# Anlage: ABR990157438859, Leistung: 7.0, Inbetriebnahme: 2024-05-23
# Anlage: ABR979186451947, Leistung: 110.0, Inbetriebnahme: 2024-05-23
# Anlage: ABR979186451947, Leistung: 48.45, Inbetriebnahme: 2024-06-14
# Anlage: ABR979186451947, Leistung: 0.8, Inbetriebnahme: 2024-09-17
# Anlage: ABR979186451947, Leistung: 10.0, Inbetriebnahme: 2024-12-12
# Anlage: ABR979186451947, Leistung: 26.88, Inbetriebnahme: 2024-12-12
# Anlage: ABR979186451947, Leistung: 100.0, Inbetriebnahme: 2025-02-20
# Anlage: ABR979186451947, Leistung: 99.24, Inbetriebnahme: nan
# Anlage: ABR979186451947, Leistung: 420.0, Inbetriebnahme: nan
# Anlage: ABR979186451947, Leistung: 141.1, Inbetriebnahme: nan
# {'1997': 1,
#  '2007': 2,
#  '2011': 3,
#  '2018': 7,
#  '2019': 10,
#  '2020': 14,
#  '2021': 18,
#  '2022': 21,
#  '2023': 36,
#  '2024': 47,
#  '2025': 48}

# %%
import math

csv_content = []
for jahr, leistung in leistungssummen.items():
    anzahl = anzahlsummen[jahr]
    print(f"Hinzufügen: Jahr {jahr}, Leistung {math.floor(leistung)}, Anzahl {anzahl}")  
 
    csv_content.append({
        "DATEINAME": "pv-anlagen",
        "RAUM": "Stadt Münster",
        "QUELLE_INSTITUTION": "Marktstammdatenregister",
        "THEMENBEREICH": 15,
        "MERKMAL": "Leistung aller Anlagen (Summe)",
        "ZEIT": jahr,
        "WERT": math.floor(leistung),
        "WERTEEINHEIT": "kWp"
    })
    csv_content.append({
        "DATEINAME": "pv-anlagen",
        "RAUM": "Stadt Münster",
        "QUELLE_INSTITUTION": "Marktstammdatenregister",
        "THEMENBEREICH": 15,
        "MERKMAL": "Anzahl aller PV-Anlagen",
        "ZEIT": jahr,
        "WERT": anzahl,
        "WERTEEINHEIT": "Anzahl"
    })

for gefiltert_row in gefiltert.itertuples():
    # Extract year only if InbetriebnahmeDatum is a string and has at least 4 characters
    inbetriebnahme = gefiltert_row.InbetriebnahmeDatum
    if isinstance(inbetriebnahme, str) and len(inbetriebnahme) >= 4:
        jahr = inbetriebnahme[:4]
        csv_content.append({
            "DATEINAME": "pv-anlagen",
            "RAUM": f"Stadt Münster - PV Anlage {gefiltert_row.EinheitName} ({math.floor(gefiltert_row.AnzahlSolarModule)}), Inbetriebnahme: {gefiltert_row.InbetriebnahmeDatum}",
            "QUELLE_INSTITUTION": "Stadtverwaltung Münster",
            "THEMENBEREICH": 15,
            "MERKMAL": "Leistung ab Jahr",
            "ZEIT": jahr,
            "WERT": gefiltert_row.Nettonennleistung,
            "WERTEEINHEIT": "kWp"
        })

csv_content
# Out:
# Hinzufügen: Jahr 1997, Leistung 5, Anzahl 1
# Hinzufügen: Jahr 2007, Leistung 9, Anzahl 2
# Hinzufügen: Jahr 2011, Leistung 16, Anzahl 3
# Hinzufügen: Jahr 2018, Leistung 60, Anzahl 7
# Hinzufügen: Jahr 2019, Leistung 89, Anzahl 10
# Hinzufügen: Jahr 2020, Leistung 238, Anzahl 14
# Hinzufügen: Jahr 2021, Leistung 378, Anzahl 18
# Hinzufügen: Jahr 2022, Leistung 482, Anzahl 21
# Hinzufügen: Jahr 2023, Leistung 994, Anzahl 36
# Hinzufügen: Jahr 2024, Leistung 1302, Anzahl 47
# Hinzufügen: Jahr 2025, Leistung 1402, Anzahl 48
# [{'DATEINAME': 'pv-anlagen',
#   'RAUM': 'Stadt Münster',
#   'QUELLE_INSTITUTION': 'Stadtverwaltung Münster',
#   'THEMENBEREICH': 15,
#   'MERKMAL': 'Leistung aller Anlagen (Summe)',
#   'ZEIT': '1997',
#   'WERT': 5,
#   'WERTEEINHEIT': 'kWp'},
#  {'DATEINAME': 'pv-anlagen',
#   'RAUM': 'Stadt Münster',
#   'QUELLE_INSTITUTION': 'Stadtverwaltung Münster',
#   'THEMENBEREICH': 15,
#   'MERKMAL': 'Anzahl aller PV-Anlagen',
#   'ZEIT': '1997',
#   'WERT': 1,
#   'WERTEEINHEIT': 'Anzahl'},
#  {'DATEINAME': 'pv-anlagen',
#   'RAUM': 'Stadt Münster',
#   'QUELLE_INSTITUTION': 'Stadtverwaltung Münster',
#   'THEMENBEREICH': 15,
#   'MERKMAL': 'Leistung aller Anlagen (Summe)',
#   'ZEIT': '2007',
#   'WERT': 9,
#   'WERTEEINHEIT': 'kWp'},
#  {'DATEINAME': 'pv-anlagen',
#   'RAUM': 'Stadt Münster',
#   'QUELLE_INSTITUTION': 'Stadtverwaltung Münster',
#   'THEMENBEREICH': 15,
#   'MERKMAL': 'Anzahl aller PV-Anlagen',
#   'ZEIT': '2007',
#   'WERT': 2,
#   'WERTEEINHEIT': 'Anzahl'},
#  {'DATEINAME': 'pv-anlagen',
#   'RAUM': 'Stadt Münster',
#   'QUELLE_INSTITUTION': 'Stadtverwaltung Münster',
#   'THEMENBEREICH': 15,
#   'MERKMAL': 'Leistung aller Anlagen (Summe)',
#   'ZEIT': '2011',
#   'WERT': 16,
#   'WERTEEINHEIT': 'kWp'},
#  {'DATEINAME': 'pv-anlagen',
#   'RAUM': 'Stadt Münster',
#   'QUELLE_INSTITUTION': 'Stadtverwaltung Münster',
#   'THEMENBEREICH': 15,
#   'MERKMAL': 'Anzahl aller PV-Anlagen',
#   'ZEIT': '2011',
#   'WERT': 3,
#   'WERTEEINHEIT': 'Anzahl'},
#  {'DATEINAME': 'pv-anlagen',
#   'RAUM': 'Stadt Münster',
#   'QUELLE_INSTITUTION': 'Stadtverwaltung Münster',
#   'THEMENBEREICH': 15,
#   'MERKMAL': 'Leistung aller Anlagen (Summe)',
#   'ZEIT': '2018',
#   'WERT': 60,
#   'WERTEEINHEIT': 'kWp'},
#  {'DATEINAME': 'pv-anlagen',
#   'RAUM': 'Stadt Münster',
#   'QUELLE_INSTITUTION': 'Stadtverwaltung Münster',
#   'THEMENBEREICH': 15,
#   'MERKMAL': 'Anzahl aller PV-Anlagen',
#   'ZEIT': '2018',
#   'WERT': 7,
#   'WERTEEINHEIT': 'Anzahl'},
#  {'DATEINAME': 'pv-anlagen',
#   'RAUM': 'Stadt Münster',
#   'QUELLE_INSTITUTION': 'Stadtverwaltung Münster',
#   'THEMENBEREICH': 15,
#   'MERKMAL': 'Leistung aller Anlagen (Summe)',
#   'ZEIT': '2019',
#   'WERT': 89,
#   'WERTEEINHEIT': 'kWp'},
#  {'DATEINAME': 'pv-anlagen',
#   'RAUM': 'Stadt Münster',
#   'QUELLE_INSTITUTION': 'Stadtverwaltung Münster',
#   'THEMENBEREICH': 15,
#   'MERKMAL': 'Anzahl aller PV-Anlagen',
#   'ZEIT': '2019',
#   'WERT': 10,
#   'WERTEEINHEIT': 'Anzahl'},
#  {'DATEINAME': 'pv-anlagen',
#   'RAUM': 'Stadt Münster',
#   'QUELLE_INSTITUTION': 'Stadtverwaltung Münster',
#   'THEMENBEREICH': 15,
#   'MERKMAL': 'Leistung aller Anlagen (Summe)',
#   'ZEIT': '2020',
#   'WERT': 238,
#   'WERTEEINHEIT': 'kWp'},
#  {'DATEINAME': 'pv-anlagen',
#   'RAUM': 'Stadt Münster',
#   'QUELLE_INSTITUTION': 'Stadtverwaltung Münster',
#   'THEMENBEREICH': 15,
#   'MERKMAL': 'Anzahl aller PV-Anlagen',
#   'ZEIT': '2020',
#   'WERT': 14,
#   'WERTEEINHEIT': 'Anzahl'},
#  {'DATEINAME': 'pv-anlagen',
#   'RAUM': 'Stadt Münster',
#   'QUELLE_INSTITUTION': 'Stadtverwaltung Münster',
#   'THEMENBEREICH': 15,
#   'MERKMAL': 'Leistung aller Anlagen (Summe)',
#   'ZEIT': '2021',
#   'WERT': 378,
#   'WERTEEINHEIT': 'kWp'},
#  {'DATEINAME': 'pv-anlagen',
#   'RAUM': 'Stadt Münster',
#   'QUELLE_INSTITUTION': 'Stadtverwaltung Münster',
#   'THEMENBEREICH': 15,
#   'MERKMAL': 'Anzahl aller PV-Anlagen',
#   'ZEIT': '2021',
#   'WERT': 18,
#   'WERTEEINHEIT': 'Anzahl'},
#  {'DATEINAME': 'pv-anlagen',
#   'RAUM': 'Stadt Münster',
#   'QUELLE_INSTITUTION': 'Stadtverwaltung Münster',
#   'THEMENBEREICH': 15,
#   'MERKMAL': 'Leistung aller Anlagen (Summe)',
#   'ZEIT': '2022',
#   'WERT': 482,
#   'WERTEEINHEIT': 'kWp'},
#  {'DATEINAME': 'pv-anlagen',
#   'RAUM': 'Stadt Münster',
#   'QUELLE_INSTITUTION': 'Stadtverwaltung Münster',
#   'THEMENBEREICH': 15,
#   'MERKMAL': 'Anzahl aller PV-Anlagen',
#   'ZEIT': '2022',
#   'WERT': 21,
#   'WERTEEINHEIT': 'Anzahl'},
#  {'DATEINAME': 'pv-anlagen',
#   'RAUM': 'Stadt Münster',
#   'QUELLE_INSTITUTION': 'Stadtverwaltung Münster',
#   'THEMENBEREICH': 15,
#   'MERKMAL': 'Leistung aller Anlagen (Summe)',
#   'ZEIT': '2023',
#   'WERT': 994,
#   'WERTEEINHEIT': 'kWp'},
#  {'DATEINAME': 'pv-anlagen',
#   'RAUM': 'Stadt Münster',
#   'QUELLE_INSTITUTION': 'Stadtverwaltung Münster',
#   'THEMENBEREICH': 15,
#   'MERKMAL': 'Anzahl aller PV-Anlagen',
#   'ZEIT': '2023',
#   'WERT': 36,
#   'WERTEEINHEIT': 'Anzahl'},
#  {'DATEINAME': 'pv-anlagen',
#   'RAUM': 'Stadt Münster',
#   'QUELLE_INSTITUTION': 'Stadtverwaltung Münster',
#   'THEMENBEREICH': 15,
#   'MERKMAL': 'Leistung aller Anlagen (Summe)',
#   'ZEIT': '2024',
#   'WERT': 1302,
#   'WERTEEINHEIT': 'kWp'},
#  {'DATEINAME': 'pv-anlagen',
#   'RAUM': 'Stadt Münster',
#   'QUELLE_INSTITUTION': 'Stadtverwaltung Münster',
#   'THEMENBEREICH': 15,
#   'MERKMAL': 'Anzahl aller PV-Anlagen',
#   'ZEIT': '2024',
#   'WERT': 47,
#   'WERTEEINHEIT': 'Anzahl'},
#  {'DATEINAME': 'pv-anlagen',
#   'RAUM': 'Stadt Münster',
#   'QUELLE_INSTITUTION': 'Stadtverwaltung Münster',
#   'THEMENBEREICH': 15,
#   'MERKMAL': 'Leistung aller Anlagen (Summe)',
#   'ZEIT': '2025',
#   'WERT': 1402,
#   'WERTEEINHEIT': 'kWp'},
#  {'DATEINAME': 'pv-anlagen',
#   'RAUM': 'Stadt Münster',
#   'QUELLE_INSTITUTION': 'Stadtverwaltung Münster',
#   'THEMENBEREICH': 15,
#   'MERKMAL': 'Anzahl aller PV-Anlagen',
#   'ZEIT': '2025',
#   'WERT': 48,
#   'WERTEEINHEIT': 'Anzahl'},
#  {'DATEINAME': 'pv-anlagen',
#   'RAUM': 'Stadt Münster - PV Anlage Stadt Münster_Bürgerzentrum Kinderhaus (56), Inbetriebnahme: 1997-09-08',
#   'QUELLE_INSTITUTION': 'Stadt Münster - Amt für Immobilienmanagement',
#   'THEMENBEREICH': 15,
#   'MERKMAL': 'Leistung ab Jahr',
#   'ZEIT': '1997',
#   'WERT': 5.0,
#   'WERTEEINHEIT': 'kWp'},
#  {'DATEINAME': 'pv-anlagen',
#   'RAUM': 'Stadt Münster - PV Anlage Erbdrostenweg (26), Inbetriebnahme: 2007-02-09',
#   'QUELLE_INSTITUTION': 'Stadt Münster - Amt für Immobilienmanagement',
#   'THEMENBEREICH': 15,
#   'MERKMAL': 'Leistung ab Jahr',
#   'ZEIT': '2007',
#   'WERT': 4.2,
#   'WERTEEINHEIT': 'kWp'},
#  {'DATEINAME': 'pv-anlagen',
#   'RAUM': 'Stadt Münster - PV Anlage Alter Postweg (36), Inbetriebnahme: 2011-02-16',
#   'QUELLE_INSTITUTION': 'Stadt Münster - Amt für Immobilienmanagement',
#   'THEMENBEREICH': 15,
#   'MERKMAL': 'Leistung ab Jahr',
#   'ZEIT': '2011',
#   'WERT': 7.1,
#   'WERTEEINHEIT': 'kWp'},
#  {'DATEINAME': 'pv-anlagen',
#   'RAUM': 'Stadt Münster - PV Anlage Stadt Münster_Kita Loddengrund (28), Inbetriebnahme: 2018-12-10',
#   'QUELLE_INSTITUTION': 'Stadt Münster - Amt für Immobilienmanagement',
#   'THEMENBEREICH': 15,
#   'MERKMAL': 'Leistung ab Jahr',
#   'ZEIT': '2018',
#   'WERT': 8.0,
#   'WERTEEINHEIT': 'kWp'},
#  {'DATEINAME': 'pv-anlagen',
#   'RAUM': 'Stadt Münster - PV Anlage Stadt Münster_Kita Burgwall (28), Inbetriebnahme: 2018-12-10',
#   'QUELLE_INSTITUTION': 'Stadt Münster - Amt für Immobilienmanagement',
#   'THEMENBEREICH': 15,
#   'MERKMAL': 'Leistung ab Jahr',
#   'ZEIT': '2018',
#   'WERT': 8.0,
#   'WERTEEINHEIT': 'kWp'},
#  {'DATEINAME': 'pv-anlagen',
#   'RAUM': 'Stadt Münster - PV Anlage Stadt Münster_Kita Legdenweg (28), Inbetriebnahme: 2018-12-10',
#   'QUELLE_INSTITUTION': 'Stadt Münster - Amt für Immobilienmanagement',
#   'THEMENBEREICH': 15,
#   'MERKMAL': 'Leistung ab Jahr',
#   'ZEIT': '2018',
#   'WERT': 8.0,
#   'WERTEEINHEIT': 'kWp'},
#  {'DATEINAME': 'pv-anlagen',
#   'RAUM': 'Stadt Münster - PV Anlage Stadt Münster_Ludgerusschule Hiltrup (66), Inbetriebnahme: 2018-12-11',
#   'QUELLE_INSTITUTION': 'Stadt Münster - Amt für Immobilienmanagement',
#   'THEMENBEREICH': 15,
#   'MERKMAL': 'Leistung ab Jahr',
#   'ZEIT': '2018',
#   'WERT': 19.8,
#   'WERTEEINHEIT': 'kWp'},
#  {'DATEINAME': 'pv-anlagen',
#   'RAUM': 'Stadt Münster - PV Anlage Kita Middelerstraße (20), Inbetriebnahme: 2019-06-17',
#   'QUELLE_INSTITUTION': 'Stadt Münster - Amt für Immobilienmanagement',
#   'THEMENBEREICH': 15,
#   'MERKMAL': 'Leistung ab Jahr',
#   'ZEIT': '2019',
#   'WERT': 5.7,
#   'WERTEEINHEIT': 'kWp'},
#  {'DATEINAME': 'pv-anlagen',
#   'RAUM': 'Stadt Münster - PV Anlage Kita Middelerstraße (20), Inbetriebnahme: 2019-06-17',
#   'QUELLE_INSTITUTION': 'Stadt Münster - Amt für Immobilienmanagement',
#   'THEMENBEREICH': 15,
#   'MERKMAL': 'Leistung ab Jahr',
#   'ZEIT': '2019',
#   'WERT': 4.0,
#   'WERTEEINHEIT': 'kWp'},
#  {'DATEINAME': 'pv-anlagen',
#   'RAUM': 'Stadt Münster - PV Anlage Hauptkläranlage Betriebsgebäude/Sozialgebäude (72), Inbetriebnahme: 2019-08-20',
#   'QUELLE_INSTITUTION': 'Stadt Münster - Amt für Immobilienmanagement',
#   'THEMENBEREICH': 15,
#   'MERKMAL': 'Leistung ab Jahr',
#   'ZEIT': '2019',
#   'WERT': 19.44,
#   'WERTEEINHEIT': 'kWp'},
#  {'DATEINAME': 'pv-anlagen',
#   'RAUM': 'Stadt Münster - PV Anlage Stadt Münster_Grundschule Wolbeck (122), Inbetriebnahme: 2020-01-30',
#   'QUELLE_INSTITUTION': 'Stadt Münster - Amt für Immobilienmanagement',
#   'THEMENBEREICH': 15,
#   'MERKMAL': 'Leistung ab Jahr',
#   'ZEIT': '2020',
#   'WERT': 30.0,
#   'WERTEEINHEIT': 'kWp'},
#  {'DATEINAME': 'pv-anlagen',
#   'RAUM': 'Stadt Münster - PV Anlage Stadt Münster_Hans-Böckler-Berufskolleg (236), Inbetriebnahme: 2020-02-12',
#   'QUELLE_INSTITUTION': 'Stadt Münster - Amt für Immobilienmanagement',
#   'THEMENBEREICH': 15,
#   'MERKMAL': 'Leistung ab Jahr',
#   'ZEIT': '2020',
#   'WERT': 60.0,
#   'WERTEEINHEIT': 'kWp'},
#  {'DATEINAME': 'pv-anlagen',
#   'RAUM': 'Stadt Münster - PV Anlage Stadt Münster_Albert-Schweitzer Schule (88), Inbetriebnahme: 2020-12-03',
#   'QUELLE_INSTITUTION': 'Stadt Münster - Amt für Immobilienmanagement',
#   'THEMENBEREICH': 15,
#   'MERKMAL': 'Leistung ab Jahr',
#   'ZEIT': '2020',
#   'WERT': 29.48,
#   'WERTEEINHEIT': 'kWp'},
#  {'DATEINAME': 'pv-anlagen',
#   'RAUM': 'Stadt Münster - PV Anlage Stadt Münster_Pascal Gymnasium (88), Inbetriebnahme: 2020-12-03',
#   'QUELLE_INSTITUTION': 'Stadt Münster - Amt für Immobilienmanagement',
#   'THEMENBEREICH': 15,
#   'MERKMAL': 'Leistung ab Jahr',
#   'ZEIT': '2020',
#   'WERT': 29.48,
#   'WERTEEINHEIT': 'kWp'},
#  {'DATEINAME': 'pv-anlagen',
#   'RAUM': 'Stadt Münster - PV Anlage Stadt Münster_Schillergymnasium (92), Inbetriebnahme: 2021-02-02',
#   'QUELLE_INSTITUTION': 'Stadt Münster - Amt für Immobilienmanagement',
#   'THEMENBEREICH': 15,
#   'MERKMAL': 'Leistung ab Jahr',
#   'ZEIT': '2021',
#   'WERT': 29.9,
#   'WERTEEINHEIT': 'kWp'},
#  {'DATEINAME': 'pv-anlagen',
#   'RAUM': 'Stadt Münster - PV Anlage Stadt Münster Kita Nordkirchenstraße 100 (16), Inbetriebnahme: 2021-08-10',
#   'QUELLE_INSTITUTION': 'Stadt Münster - Amt für Immobilienmanagement',
#   'THEMENBEREICH': 15,
#   'MERKMAL': 'Leistung ab Jahr',
#   'ZEIT': '2021',
#   'WERT': 5.92,
#   'WERTEEINHEIT': 'kWp'},
#  {'DATEINAME': 'pv-anlagen',
#   'RAUM': 'Stadt Münster - PV Anlage Stadt Münster Nottulner Landweg 1 (16), Inbetriebnahme: 2021-08-10',
#   'QUELLE_INSTITUTION': 'Stadt Münster - Amt für Immobilienmanagement',
#   'THEMENBEREICH': 15,
#   'MERKMAL': 'Leistung ab Jahr',
#   'ZEIT': '2021',
#   'WERT': 5.0,
#   'WERTEEINHEIT': 'kWp'},
#  {'DATEINAME': 'pv-anlagen',
#   'RAUM': 'Stadt Münster - PV Anlage Stadt Münster_Freiherr-vom-Stein Gymnasium (300), Inbetriebnahme: 2021-11-23',
#   'QUELLE_INSTITUTION': 'Stadt Münster - Amt für Immobilienmanagement',
#   'THEMENBEREICH': 15,
#   'MERKMAL': 'Leistung ab Jahr',
#   'ZEIT': '2021',
#   'WERT': 99.0,
#   'WERTEEINHEIT': 'kWp'},
#  {'DATEINAME': 'pv-anlagen',
#   'RAUM': 'Stadt Münster - PV Anlage Stadt Münster_Bodelschwingschule (165), Inbetriebnahme: 2022-01-01',
#   'QUELLE_INSTITUTION': 'Stadt Münster - Amt für Immobilienmanagement',
#   'THEMENBEREICH': 15,
#   'MERKMAL': 'Leistung ab Jahr',
#   'ZEIT': '2022',
#   'WERT': 55.0,
#   'WERTEEINHEIT': 'kWp'},
#  {'DATEINAME': 'pv-anlagen',
#   'RAUM': 'Stadt Münster - PV Anlage Stadt Münster_Stadtteilhaus Lorenz Süd (142), Inbetriebnahme: 2022-05-11',
#   'QUELLE_INSTITUTION': 'Stadt Münster - Amt für Immobilienmanagement',
#   'THEMENBEREICH': 15,
#   'MERKMAL': 'Leistung ab Jahr',
#   'ZEIT': '2022',
#   'WERT': 45.0,
#   'WERTEEINHEIT': 'kWp'},
#  {'DATEINAME': 'pv-anlagen',
#   'RAUM': 'Stadt Münster - PV Anlage Stadt Münster_Kreuzschule (12), Inbetriebnahme: 2022-08-29',
#   'QUELLE_INSTITUTION': 'Stadt Münster - Amt für Immobilienmanagement',
#   'THEMENBEREICH': 15,
#   'MERKMAL': 'Leistung ab Jahr',
#   'ZEIT': '2022',
#   'WERT': 4.0,
#   'WERTEEINHEIT': 'kWp'},
#  {'DATEINAME': 'pv-anlagen',
#   'RAUM': 'Stadt Münster - PV Anlage Stadt Münster_Erna-de-Vries Schule (152), Inbetriebnahme: 2023-02-28',
#   'QUELLE_INSTITUTION': 'Stadt Münster - Amt für Immobilienmanagement',
#   'THEMENBEREICH': 15,
#   'MERKMAL': 'Leistung ab Jahr',
#   'ZEIT': '2023',
#   'WERT': 57.76,
#   'WERTEEINHEIT': 'kWp'},
#  {'DATEINAME': 'pv-anlagen',
#   'RAUM': 'Stadt Münster - PV Anlage Stadt Münster_Schulzentrum Kinderhaus (271), Inbetriebnahme: 2023-04-11',
#   'QUELLE_INSTITUTION': 'Stadt Münster - Amt für Immobilienmanagement',
#   'THEMENBEREICH': 15,
#   'MERKMAL': 'Leistung ab Jahr',
#   'ZEIT': '2023',
#   'WERT': 96.2,
#   'WERTEEINHEIT': 'kWp'},
#  {'DATEINAME': 'pv-anlagen',
#   'RAUM': 'Stadt Münster - PV Anlage Stadt Münster_Kardinal-von-Galen Schule_Handorf (66), Inbetriebnahme: 2023-07-04',
#   'QUELLE_INSTITUTION': 'Stadt Münster - Amt für Immobilienmanagement',
#   'THEMENBEREICH': 15,
#   'MERKMAL': 'Leistung ab Jahr',
#   'ZEIT': '2023',
#   'WERT': 24.75,
#   'WERTEEINHEIT': 'kWp'},
#  {'DATEINAME': 'pv-anlagen',
#   'RAUM': 'Stadt Münster - PV Anlage Stadt Münster_Pascal Gymnasium_3 Fach Sporthalle (294), Inbetriebnahme: 2023-08-30',
#   'QUELLE_INSTITUTION': 'Stadt Münster - Amt für Immobilienmanagement',
#   'THEMENBEREICH': 15,
#   'MERKMAL': 'Leistung ab Jahr',
#   'ZEIT': '2023',
#   'WERT': 99.96,
#   'WERTEEINHEIT': 'kWp'},
#  {'DATEINAME': 'pv-anlagen',
#   'RAUM': 'Stadt Münster - PV Anlage Stadt Münster_Gesamtschule Mitte (154), Inbetriebnahme: 2023-10-19',
#   'QUELLE_INSTITUTION': 'Stadt Münster - Amt für Immobilienmanagement',
#   'THEMENBEREICH': 15,
#   'MERKMAL': 'Leistung ab Jahr',
#   'ZEIT': '2023',
#   'WERT': 60.0,
#   'WERTEEINHEIT': 'kWp'},
#  {'DATEINAME': 'pv-anlagen',
#   'RAUM': 'Stadt Münster - PV Anlage Inkingrodde (8), Inbetriebnahme: 2023-11-27',
#   'QUELLE_INSTITUTION': 'Stadt Münster - Amt für Immobilienmanagement',
#   'THEMENBEREICH': 15,
#   'MERKMAL': 'Leistung ab Jahr',
#   'ZEIT': '2023',
#   'WERT': 3.0,
#   'WERTEEINHEIT': 'kWp'},
#  {'DATEINAME': 'pv-anlagen',
#   'RAUM': 'Stadt Münster - PV Anlage Zum Häpper (22), Inbetriebnahme: 2023-11-30',
#   'QUELLE_INSTITUTION': 'Stadt Münster - Amt für Immobilienmanagement',
#   'THEMENBEREICH': 15,
#   'MERKMAL': 'Leistung ab Jahr',
#   'ZEIT': '2023',
#   'WERT': 8.14,
#   'WERTEEINHEIT': 'kWp'},
#  {'DATEINAME': 'pv-anlagen',
#   'RAUM': 'Stadt Münster - PV Anlage Steinbrede (20), Inbetriebnahme: 2023-11-30',
#   'QUELLE_INSTITUTION': 'Stadt Münster - Amt für Immobilienmanagement',
#   'THEMENBEREICH': 15,
#   'MERKMAL': 'Leistung ab Jahr',
#   'ZEIT': '2023',
#   'WERT': 7.0,
#   'WERTEEINHEIT': 'kWp'},
#  {'DATEINAME': 'pv-anlagen',
#   'RAUM': 'Stadt Münster - PV Anlage Coermühle (32), Inbetriebnahme: 2023-11-30',
#   'QUELLE_INSTITUTION': 'Stadt Münster - Amt für Immobilienmanagement',
#   'THEMENBEREICH': 15,
#   'MERKMAL': 'Leistung ab Jahr',
#   'ZEIT': '2023',
#   'WERT': 10.0,
#   'WERTEEINHEIT': 'kWp'},
#  {'DATEINAME': 'pv-anlagen',
#   'RAUM': 'Stadt Münster - PV Anlage Malteserstraße (22), Inbetriebnahme: 2023-12-06',
#   'QUELLE_INSTITUTION': 'Stadt Münster - Amt für Immobilienmanagement',
#   'THEMENBEREICH': 15,
#   'MERKMAL': 'Leistung ab Jahr',
#   'ZEIT': '2023',
#   'WERT': 8.14,
#   'WERTEEINHEIT': 'kWp'},
#  {'DATEINAME': 'pv-anlagen',
#   'RAUM': 'Stadt Münster - PV Anlage Hessenbusch (20), Inbetriebnahme: 2023-12-08',
#   'QUELLE_INSTITUTION': 'Stadt Münster - Amt für Immobilienmanagement',
#   'THEMENBEREICH': 15,
#   'MERKMAL': 'Leistung ab Jahr',
#   'ZEIT': '2023',
#   'WERT': 7.0,
#   'WERTEEINHEIT': 'kWp'},
#  {'DATEINAME': 'pv-anlagen',
#   'RAUM': 'Stadt Münster - PV Anlage Eschstraße (44), Inbetriebnahme: 2023-12-08',
#   'QUELLE_INSTITUTION': 'Stadt Münster - Amt für Immobilienmanagement',
#   'THEMENBEREICH': 15,
#   'MERKMAL': 'Leistung ab Jahr',
#   'ZEIT': '2023',
#   'WERT': 15.0,
#   'WERTEEINHEIT': 'kWp'},
#  {'DATEINAME': 'pv-anlagen',
#   'RAUM': 'Stadt Münster - PV Anlage Stadt Münster_Feuerwehrhaus Sprakel (18), Inbetriebnahme: 2023-12-12',
#   'QUELLE_INSTITUTION': 'Stadt Münster - Amt für Immobilienmanagement',
#   'THEMENBEREICH': 15,
#   'MERKMAL': 'Leistung ab Jahr',
#   'ZEIT': '2023',
#   'WERT': 6.0,
#   'WERTEEINHEIT': 'kWp'},
#  {'DATEINAME': 'pv-anlagen',
#   'RAUM': 'Stadt Münster - PV Anlage Stadt Münster_Feuerwache 2 (242), Inbetriebnahme: 2023-12-12',
#   'QUELLE_INSTITUTION': 'Stadt Münster - Amt für Immobilienmanagement',
#   'THEMENBEREICH': 15,
#   'MERKMAL': 'Leistung ab Jahr',
#   'ZEIT': '2023',
#   'WERT': 75.0,
#   'WERTEEINHEIT': 'kWp'},
#  {'DATEINAME': 'pv-anlagen',
#   'RAUM': 'Stadt Münster - PV Anlage Hauptkläranlage ÜSS-Anlage (96), Inbetriebnahme: 2023-12-21',
#   'QUELLE_INSTITUTION': 'Stadt Münster - Amt für Immobilienmanagement',
#   'THEMENBEREICH': 15,
#   'MERKMAL': 'Leistung ab Jahr',
#   'ZEIT': '2023',
#   'WERT': 35.0,
#   'WERTEEINHEIT': 'kWp'},
#  {'DATEINAME': 'pv-anlagen',
#   'RAUM': 'Stadt Münster - PV Anlage Stadt Münster_Primusschule (1) (54), Inbetriebnahme: 2024-02-09',
#   'QUELLE_INSTITUTION': 'Stadt Münster - Amt für Immobilienmanagement',
#   'THEMENBEREICH': 15,
#   'MERKMAL': 'Leistung ab Jahr',
#   'ZEIT': '2024',
#   'WERT': 20.0,
#   'WERTEEINHEIT': 'kWp'},
#  {'DATEINAME': 'pv-anlagen',
#   'RAUM': 'Stadt Münster - PV Anlage Stadt Münster_Stadtbücherei (72), Inbetriebnahme: 2024-02-21',
#   'QUELLE_INSTITUTION': 'Stadt Münster - Amt für Immobilienmanagement',
#   'THEMENBEREICH': 15,
#   'MERKMAL': 'Leistung ab Jahr',
#   'ZEIT': '2024',
#   'WERT': 29.75,
#   'WERTEEINHEIT': 'kWp'},
#  {'DATEINAME': 'pv-anlagen',
#   'RAUM': 'Stadt Münster - PV Anlage Stadt Münster_Erna-de-Vries Schule_Erweiterung (48), Inbetriebnahme: 2024-03-15',
#   'QUELLE_INSTITUTION': 'Stadt Münster - Amt für Immobilienmanagement',
#   'THEMENBEREICH': 15,
#   'MERKMAL': 'Leistung ab Jahr',
#   'ZEIT': '2024',
#   'WERT': 15.0,
#   'WERTEEINHEIT': 'kWp'},
#  {'DATEINAME': 'pv-anlagen',
#   'RAUM': 'Stadt Münster - PV Anlage Stadt Münster_Gesamt Schule West_Sporthalle (96), Inbetriebnahme: 2024-04-22',
#   'QUELLE_INSTITUTION': 'Stadt Münster - Amt für Immobilienmanagement',
#   'THEMENBEREICH': 15,
#   'MERKMAL': 'Leistung ab Jahr',
#   'ZEIT': '2024',
#   'WERT': 29.76,
#   'WERTEEINHEIT': 'kWp'},
#  {'DATEINAME': 'pv-anlagen',
#   'RAUM': 'Stadt Münster - PV Anlage Am Hangkamp (32), Inbetriebnahme: 2024-05-13',
#   'QUELLE_INSTITUTION': 'Stadt Münster - Amt für Immobilienmanagement',
#   'THEMENBEREICH': 15,
#   'MERKMAL': 'Leistung ab Jahr',
#   'ZEIT': '2024',
#   'WERT': 10.0,
#   'WERTEEINHEIT': 'kWp'},
#  {'DATEINAME': 'pv-anlagen',
#   'RAUM': 'Stadt Münster - PV Anlage Heidestraße (20), Inbetriebnahme: 2024-05-23',
#   'QUELLE_INSTITUTION': 'Stadt Münster - Amt für Immobilienmanagement',
#   'THEMENBEREICH': 15,
#   'MERKMAL': 'Leistung ab Jahr',
#   'ZEIT': '2024',
#   'WERT': 7.0,
#   'WERTEEINHEIT': 'kWp'},
#  {'DATEINAME': 'pv-anlagen',
#   'RAUM': 'Stadt Münster - PV Anlage Stadt Münster_Südbad (320), Inbetriebnahme: 2024-05-23',
#   'QUELLE_INSTITUTION': 'Stadt Münster - Amt für Immobilienmanagement',
#   'THEMENBEREICH': 15,
#   'MERKMAL': 'Leistung ab Jahr',
#   'ZEIT': '2024',
#   'WERT': 110.0,
#   'WERTEEINHEIT': 'kWp'},
#  {'DATEINAME': 'pv-anlagen',
#   'RAUM': 'Stadt Münster - PV Anlage Stadt Münster_Gesundheitsamt (114), Inbetriebnahme: 2024-06-14',
#   'QUELLE_INSTITUTION': 'Stadt Münster - Amt für Immobilienmanagement',
#   'THEMENBEREICH': 15,
#   'MERKMAL': 'Leistung ab Jahr',
#   'ZEIT': '2024',
#   'WERT': 48.45,
#   'WERTEEINHEIT': 'kWp'},
#  {'DATEINAME': 'pv-anlagen',
#   'RAUM': 'Stadt Münster - PV Anlage Stadt Münster_Friedhof Angelmodde (2), Inbetriebnahme: 2024-09-17',
#   'QUELLE_INSTITUTION': 'Stadt Münster - Amt für Immobilienmanagement',
#   'THEMENBEREICH': 15,
#   'MERKMAL': 'Leistung ab Jahr',
#   'ZEIT': '2024',
#   'WERT': 0.8,
#   'WERTEEINHEIT': 'kWp'},
#  {'DATEINAME': 'pv-anlagen',
#   'RAUM': 'Stadt Münster - PV Anlage Stadt Münster_Schillergymnasium (28), Inbetriebnahme: 2024-12-12',
#   'QUELLE_INSTITUTION': 'Stadt Münster - Amt für Immobilienmanagement',
#   'THEMENBEREICH': 15,
#   'MERKMAL': 'Leistung ab Jahr',
#   'ZEIT': '2024',
#   'WERT': 10.0,
#   'WERTEEINHEIT': 'kWp'},
#  {'DATEINAME': 'pv-anlagen',
#   'RAUM': 'Stadt Münster - PV Anlage Stadt Münster_Pleisterschule (64), Inbetriebnahme: 2024-12-12',
#   'QUELLE_INSTITUTION': 'Stadt Münster - Amt für Immobilienmanagement',
#   'THEMENBEREICH': 15,
#   'MERKMAL': 'Leistung ab Jahr',
#   'ZEIT': '2024',
#   'WERT': 26.88,
#   'WERTEEINHEIT': 'kWp'},
#  {'DATEINAME': 'pv-anlagen',
#   'RAUM': 'Stadt Münster - PV Anlage Stadt Münster_Grundschule Sprakel_Zweifachsporthalle (240), Inbetriebnahme: 2025-02-20',
#   'QUELLE_INSTITUTION': 'Stadt Münster - Amt für Immobilienmanagement',
#   'THEMENBEREICH': 15,
#   'MERKMAL': 'Leistung ab Jahr',
#   'ZEIT': '2025',
#   'WERT': 100.0,
#   'WERTEEINHEIT': 'kWp'}]

# %%
# script zum Schreiben der CSV-Datei
import csv
# Schreibe die CSV mit Semikolon als Trennzeichen
csv.register_dialect('semicolon', delimiter=';', quoting=csv.QUOTE_MINIMAL)
output_file = 'pv_anlagen_stadt_muenster.csv'
with open(output_file, mode='w', newline='', encoding='utf-8') as file:
    writer = csv.DictWriter(file, dialect='semicolon', fieldnames=["DATEINAME", "RAUM", "QUELLE_INSTITUTION", "THEMENBEREICH", "MERKMAL", "ZEIT", "WERT", "WERTEEINHEIT"])
    writer.writeheader()
    for row in csv_content:
        writer.writerow(row)
